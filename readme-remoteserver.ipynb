# %% [markdown]
# # FlashNet

# %% [markdown]
# We will use Tencent I/O traces that were replayed on our NVMe device. This data is ready to be used for training after applying some preprocessing. As for the raw version of Tencent trace, it can be downloaded here: https://www.googleapis.com/drive/v3/files/1Xj6rFBOsY9Wt_XlCiAiZn7LfSCAYy1AB?alt=media&key=AIzaSyBbUdTut1W8uzPO1nzCmcHFIw0KsuO3Dfo

# %% [markdown]
# #### Goal
# This notebook will guide you through the process of preparing a trace profile to train a Neural Network (NN) model for performing per-IO admission control.

# %% [markdown]
# ## Setup Connection

# %% [markdown]
# Connect to Pre-made Lease

# %% [markdown]
# **How to create Lease at Chameleon Cloud?**
#
# * Create Reservation <br>
#     Go to https://chi.tacc.chameleoncloud.org/project/ or https://chi.uc.chameleoncloud.org/project/
#
#     Reserve Physical Host
#     - click "Leases" => "+ Create Lease"
#     - lease name = "trovi-ceph"
#     - "$node_type", "storage_nvme"
#     - Max lease: 7 days
#
# * Launching an Instance
#     - In the sidebar, click Compute, then click Instances
#     - Click on the Launch Instance
#         + pick the correct reservation
#         + count = 1
#         + Image: CC-Ubuntu20.04
#     - Choose the ssh key
#
# * Allocate floating IPs
#     - Book the IP interface
#         + Click "Network -> Floating IPs -> Allocate IP To Project"
#         + Write description (optional)
#         + Click "Allocate IP"
#     - Click "Associate" OR click "attach interface"
#         + Click "Network -> Floating IPs"
#     - Wait a few minutes until node spawned
#
# * If you can't access the cc user on SSH
#     - open the console terminal via the website
#     - edit the .ssh/authorized_keys and add your pub_key manually!!!
#     - now, the hostname will be different
#     - run "sudo dhclient" from the web-based ssh console

# %% [markdown]
# Declare basic variables for ssh

# %%
export ip_addr="192.5.86.149"
export SSHKEY_NAME="$USER-flashnet"
export SSHKEY_FILE="$HOME/.ssh/$SSHKEY_NAME"
export USER="$USER"

# %% [markdown]
# Create ssh folder

# %%
mkdir -p ~/.ssh
echo "Host *" > ~/.ssh/config
echo " StrictHostKeyChecking no" >> ~/.ssh/config
sudo rm -rf output/*

# %% [markdown]
# Create ssh key pair

# %%
rm -rf $HOME/.ssh/$USER-*
ssh-keygen -t rsa -b 4096  -P '' -C $SSHKEY_NAME -f $SSHKEY_FILE <<< y
echo "SSH key with name: $SSHKEY_NAME created"
# Out:
# Generating public/private rsa key pair.
# Your identification has been saved in /home/rani_api3939_gmail_com/.ssh/rani_api3939_gmail_com-flashnet
# Your public key has been saved in /home/rani_api3939_gmail_com/.ssh/rani_api3939_gmail_com-flashnet.pub
# The key fingerprint is:
# SHA256:CGqbJS2f1xOtaLNCkLAiB3pjit8KQJUqudvgaqUZvMc rani_api3939_gmail_com-flashnet
# The key's randomart image is:
# +---[RSA 4096]----+
# |   ..            |
# |o ..             |
# |.*...            |
# |O.Bo . . .       |
# |B*=oo . S .      |
# |*+ O.. o o       |
# |o=Xoo = +        |
# |.BoEoo o .       |
# |+ o. ..          |
# +----[SHA256]-----+
# SSH key with name: rani_api3939_gmail_com-flashnet created

# %% [markdown]
# Add this Trovi session machine's public key to reserved node

# %%
pubkey=`cat $SSHKEY_FILE.pub`
echo "echo \"$pubkey\" >> ~/.ssh/authorized_keys"
echo "chmod 644 ~/.ssh/authorized_keys"
echo "echo 'StrictHostKeyChecking no' > ~/.ssh/config; chmod go-rw ~/.ssh/config"
# Out:
# echo "ssh-rsa ... rani_api3939_gmail_com-flashnet" >> ~/.ssh/authorized_keys
# chmod 644 ~/.ssh/authorized_keys
# echo 'StrictHostKeyChecking no' > ~/.ssh/config; chmod go-rw ~/.ssh/config

# %% [markdown]
# Add the output of above cell to the reserved node.
#
# Steps:
# 1. Open your local terminal
# 2. Connect to the node (ssh cc@xxx.xx.xx)
# 3. Copy the output of cell above and paste to terminal

# %% [markdown]
# ### Check Connection

# %%
ssh_command="ssh -o \"StrictHostKeyChecking no\" -i $SSHKEY_FILE cc@$ip_addr"
eval "$ssh_command" pwd 
wait_ssh "$ip_addr"
# Out:
# /home/cc
# Waiting up to 300 seconds for SSH on 192.5.86.149...
# SSH is running!

# %% [markdown]
# If a specific node is used, then for some reasons rebuilding the node is needed, **run this cell after the node has been rebuilt**. Otherwise, ignore.

# %%
eval "$ssh_command" /bin/bash << EOF
    ssh-keygen -f "/home/$USER/.ssh/known_hosts" -R $ip_addr
EOF

# %% [markdown]
# ## Step-by-step Guideline:

# %%
eval "$ssh_command" /bin/bash << EOF
    git clone https://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@github.com/daniarherikurniawan/flashnet-trovi.git
    cd flashnet-trovi
    find . -type f -iname "*.sh" -exec chmod +x {} \;
    find . -type f -iname "*.py" -exec chmod +x {} \;
    pwd
    sudo chown cc -R .
EOF
# Out:
# Cloning into 'flashnet-trovi'...
# /home/cc/flashnet-trovi

# %% [markdown]
# ### 0. Install Conda Dependencies

# %%
# Creating conda env named "flashnet-trovi-env"
eval "$ssh_command" /bin/bash << EOF
    cd flashnet-trovi
    ./install_conda_deps.sh
EOF
# Out:
# Anaconda has already installed.
# no change     /home/cc/anaconda3/condabin/conda
# no change     /home/cc/anaconda3/bin/conda
# no change     /home/cc/anaconda3/bin/conda-env
# no change     /home/cc/anaconda3/bin/activate
# no change     /home/cc/anaconda3/bin/deactivate
# no change     /home/cc/anaconda3/etc/profile.d/conda.sh
# no change     /home/cc/anaconda3/etc/fish/conf.d/conda.fish
# no change     /home/cc/anaconda3/shell/condabin/Conda.psm1
# no change     /home/cc/anaconda3/shell/condabin/conda-hook.ps1
# no change     /home/cc/anaconda3/lib/python3.9/site-packages/xontrib/conda.xsh
# no change     /home/cc/anaconda3/etc/profile.d/conda.csh
# no change     /home/cc/.zshrc
# No action taken.
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/cc/anaconda3/envs/flashnet-trovi-env
#
#   added / updated specs:
#     - python=3.8
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main None
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu None
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2023.01.10-h06a4308_0 None
#   certifi            pkgs/main/linux-64::certifi-2022.12.7-py38h06a4308_0 None
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.38-h1181459_1 None
#   libffi             pkgs/main/linux-64::libffi-3.4.2-h6a678d5_6 None
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1 None
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1 None
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1 None
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0 None
#   openssl            pkgs/main/linux-64::openssl-1.1.1s-h7f8727e_0 None
#   pip                pkgs/main/linux-64::pip-22.3.1-py38h06a4308_0 None
#   python             pkgs/main/linux-64::python-3.8.16-h7a1cb2a_2 None
#   readline           pkgs/main/linux-64::readline-8.2-h5eee18b_0 None
#   setuptools         pkgs/main/linux-64::setuptools-65.6.3-py38h06a4308_0 None
#   sqlite             pkgs/main/linux-64::sqlite-3.40.1-h5082296_0 None
#   tk                 pkgs/main/linux-64::tk-8.6.12-h1ccaba5_0 None
#   wheel              pkgs/main/noarch::wheel-0.37.1-pyhd3eb1b0_0 None
#   xz                 pkgs/main/linux-64::xz-5.2.10-h5eee18b_1 None
#   zlib               pkgs/main/linux-64::zlib-1.2.13-h5eee18b_0 None
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# #
# # To activate this environment, use
# #
# #     $ conda activate flashnet-trovi-env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Retrieving notices: ...working... done
# /home/cc/anaconda3/envs/flashnet-trovi-env/bin/pip
# pip 22.3.1 from /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages/pip (python 3.8)
# Collecting tensorflow==2.7.0
#   Using cached tensorflow-2.7.0-cp38-cp38-manylinux2010_x86_64.whl (489.6 MB)
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Using cached tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
# Collecting protobuf>=3.9.2
#   Using cached protobuf-4.21.12-cp37-abi3-manylinux2014_x86_64.whl (409 kB)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
# Collecting six>=1.12.0
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.51.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting keras<2.8,>=2.7.0rc0
#   Using cached keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
# Collecting absl-py>=0.4.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting libclang>=9.0.1
#   Using cached libclang-15.0.6.1-py2.py3-none-manylinux2010_x86_64.whl (21.5 MB)
# Collecting typing-extensions>=3.6.6
#   Using cached typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting flatbuffers<3.0,>=1.12
#   Using cached flatbuffers-2.0.7-py2.py3-none-any.whl (26 kB)
# Collecting gast<0.5.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting numpy>=1.14.5
#   Using cached numpy-1.24.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorflow==2.7.0) (0.37.1)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-1.14.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (81 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting tensorboard~=2.6
#   Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.21.0
#   Using cached tensorflow_io_gcs_filesystem-0.30.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
# Requirement already satisfied: setuptools>=41.0.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (65.6.3)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.16.0-py2.py3-none-any.whl (177 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting werkzeug>=1.0.1
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Collecting protobuf>=3.9.2
#   Using cached protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Using cached importlib_metadata-6.0.0-py3-none-any.whl (21 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (2022.12.7)
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting MarkupSafe>=2.1.1
#   Using cached MarkupSafe-2.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.12.0-py3-none-any.whl (6.6 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: tensorflow-estimator, tensorboard-plugin-wit, pyasn1, libclang, keras, flatbuffers, charset-normalizer, zipp, wrapt, urllib3, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, six, rsa, pyasn1-modules, protobuf, oauthlib, numpy, MarkupSafe, idna, grpcio, gast, cachetools, absl-py, werkzeug, requests, opt-einsum, keras-preprocessing, importlib-metadata, h5py, google-pasta, google-auth, astunparse, requests-oauthlib, markdown, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed MarkupSafe-2.1.2 absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.0 charset-normalizer-3.0.1 flatbuffers-2.0.7 gast-0.4.0 google-auth-2.16.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.51.1 h5py-3.8.0 idna-3.4 importlib-metadata-6.0.0 keras-2.7.0 keras-preprocessing-1.1.2 libclang-15.0.6.1 markdown-3.4.1 numpy-1.24.1 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.20.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.28.2 requests-oauthlib-1.3.1 rsa-4.9 six-1.16.0 tensorboard-2.11.2 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.7.0 tensorflow-estimator-2.7.0 tensorflow-io-gcs-filesystem-0.30.0 termcolor-2.2.0 typing-extensions-4.4.0 urllib3-1.26.14 werkzeug-2.2.2 wrapt-1.14.1 zipp-3.12.0
# Requirement already satisfied: numpy in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (1.24.1)
# Collecting pandas
#   Using cached pandas-1.5.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
# Collecting python-dateutil>=2.8.1
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
# Requirement already satisfied: numpy>=1.20.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from pandas) (1.24.1)
# Requirement already satisfied: six>=1.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, python-dateutil, pandas
# Successfully installed pandas-1.5.3 python-dateutil-2.8.2 pytz-2022.7.1
# Collecting scikit-learn
#   Using cached scikit_learn-1.2.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
# Collecting joblib>=1.1.1
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting scipy>=1.3.2
#   Using cached scipy-1.10.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
# Requirement already satisfied: numpy>=1.17.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from scikit-learn) (1.24.1)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.1 scipy-1.10.0 threadpoolctl-3.1.0
# Collecting statsmodels
#   Using cached statsmodels-0.13.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
# Collecting packaging>=21.3
#   Using cached packaging-23.0-py3-none-any.whl (42 kB)
# Requirement already satisfied: pandas>=0.25 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from statsmodels) (1.5.3)
# Collecting patsy>=0.5.2
#   Using cached patsy-0.5.3-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: scipy>=1.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from statsmodels) (1.10.0)
# Requirement already satisfied: numpy>=1.17 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from statsmodels) (1.24.1)
# Requirement already satisfied: pytz>=2020.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: patsy, packaging, statsmodels
# Successfully installed packaging-23.0 patsy-0.5.3 statsmodels-0.13.5
# Collecting matplotlib
#   Using cached matplotlib-3.6.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.4 MB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Requirement already satisfied: packaging>=20.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib) (23.0)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
# Collecting pyparsing>=2.2.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.19 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib) (1.24.1)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
# Requirement already satisfied: six>=1.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.4 matplotlib-3.6.3 pillow-9.4.0 pyparsing-3.0.9
# Collecting future
#   Using cached future-0.18.3-py3-none-any.whl
# Installing collected packages: future
# Successfully installed future-0.18.3
# Collecting onnx
#   Using cached onnx-1.13.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
# Requirement already satisfied: numpy>=1.16.6 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from onnx) (1.24.1)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from onnx) (4.4.0)
# Requirement already satisfied: protobuf<4,>=3.20.2 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from onnx) (3.20.3)
# Installing collected packages: onnx
# Successfully installed onnx-1.13.0
# Collecting mpi
#   Using cached mpi-1.0.0-py3-none-any.whl (106 kB)
# Installing collected packages: mpi
# Successfully installed mpi-1.0.0
# Collecting tqdm
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.64.1
# Collecting pydot
#   Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: pyparsing>=2.1.4 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from pydot) (3.0.9)
# Installing collected packages: pydot
# Successfully installed pydot-1.4.2
# Collecting ipympl
#   Using cached ipympl-0.9.2-py2.py3-none-any.whl (510 kB)
# Collecting ipython<9
#   Using cached ipython-8.9.0-py3-none-any.whl (783 kB)
# Collecting ipython-genutils
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipympl) (1.24.1)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipympl) (3.6.3)
# Collecting ipywidgets<9,>=7.6.0
#   Using cached ipywidgets-8.0.4-py3-none-any.whl (137 kB)
# Requirement already satisfied: pillow in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipympl) (9.4.0)
# Collecting traitlets<6
#   Using cached traitlets-5.9.0-py3-none-any.whl (117 kB)
# Collecting prompt-toolkit<3.1.0,>=3.0.30
#   Using cached prompt_toolkit-3.0.36-py3-none-any.whl (386 kB)
# Collecting pexpect>4.3
#   Using cached pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
# Collecting backcall
#   Using cached backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting decorator
#   Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting stack-data
#   Using cached stack_data-0.6.2-py3-none-any.whl (24 kB)
# Collecting pygments>=2.4.0
#   Using cached Pygments-2.14.0-py3-none-any.whl (1.1 MB)
# Collecting pickleshare
#   Using cached pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting jedi>=0.16
#   Using cached jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
# Collecting matplotlib-inline
#   Using cached matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting ipykernel>=4.5.1
#   Using cached ipykernel-6.21.1-py3-none-any.whl (149 kB)
# Collecting widgetsnbextension~=4.0
#   Using cached widgetsnbextension-4.0.5-py3-none-any.whl (2.0 MB)
# Collecting jupyterlab-widgets~=3.0
#   Using cached jupyterlab_widgets-3.0.5-py3-none-any.whl (384 kB)
# Requirement already satisfied: cycler>=0.10 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.0.7)
# Collecting nest-asyncio
#   Using cached nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Collecting psutil
#   Using cached psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
# Collecting pyzmq>=17
#   Using cached pyzmq-25.0.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
# Collecting debugpy>=1.6.5
#   Using cached debugpy-1.6.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Collecting tornado>=6.1
#   Using cached tornado-6.2-cp37-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423 kB)
# Collecting jupyter-core!=5.0.*,>=4.12
#   Using cached jupyter_core-5.2.0-py3-none-any.whl (94 kB)
# Collecting comm>=0.1.1
#   Using cached comm-0.1.2-py3-none-any.whl (6.5 kB)
# Collecting jupyter-client>=6.1.12
#   Using cached jupyter_client-8.0.2-py3-none-any.whl (103 kB)
# Collecting parso<0.9.0,>=0.8.0
#   Using cached parso-0.8.3-py2.py3-none-any.whl (100 kB)
# Collecting ptyprocess>=0.5
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth
#   Using cached wcwidth-0.2.6-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: six>=1.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Collecting executing>=1.2.0
#   Using cached executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting pure-eval
#   Using cached pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting asttokens>=2.1.0
#   Using cached asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.0.0)
# Collecting platformdirs>=2.5
#   Using cached platformdirs-2.6.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: zipp>=0.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (3.12.0)
# Installing collected packages: wcwidth, pure-eval, ptyprocess, pickleshare, ipython-genutils, executing, backcall, widgetsnbextension, traitlets, tornado, pyzmq, pygments, psutil, prompt-toolkit, platformdirs, pexpect, parso, nest-asyncio, jupyterlab-widgets, decorator, debugpy, asttokens, stack-data, matplotlib-inline, jupyter-core, jedi, comm, jupyter-client, ipython, ipykernel, ipywidgets, ipympl
# Successfully installed asttokens-2.2.1 backcall-0.2.0 comm-0.1.2 debugpy-1.6.6 decorator-5.1.1 executing-1.2.0 ipykernel-6.21.1 ipympl-0.9.2 ipython-8.9.0 ipython-genutils-0.2.0 ipywidgets-8.0.4 jedi-0.18.2 jupyter-client-8.0.2 jupyter-core-5.2.0 jupyterlab-widgets-3.0.5 matplotlib-inline-0.1.6 nest-asyncio-1.5.6 parso-0.8.3 pexpect-4.8.0 pickleshare-0.7.5 platformdirs-2.6.2 prompt-toolkit-3.0.36 psutil-5.9.4 ptyprocess-0.7.0 pure-eval-0.2.2 pygments-2.14.0 pyzmq-25.0.0 stack-data-0.6.2 tornado-6.2 traitlets-5.9.0 wcwidth-0.2.6 widgetsnbextension-4.0.5
# Collecting seaborn
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from seaborn) (1.24.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from seaborn) (3.6.3)
# Requirement already satisfied: pandas>=0.25 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# Collecting xgboost
#   Using cached xgboost-1.7.3-py3-none-manylinux2014_x86_64.whl (193.6 MB)
# Requirement already satisfied: scipy in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from xgboost) (1.10.0)
# Requirement already satisfied: numpy in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from xgboost) (1.24.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.3
# Collecting catboost
#   Using cached catboost-1.1.1-cp38-none-manylinux1_x86_64.whl (76.6 MB)
# Requirement already satisfied: six in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: scipy in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from catboost) (1.10.0)
# Requirement already satisfied: pandas>=0.24.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from catboost) (1.5.3)
# Collecting plotly
#   Using cached plotly-5.13.0-py2.py3-none-any.whl (15.2 MB)
# Collecting graphviz
#   Using cached graphviz-0.20.1-py3-none-any.whl (47 kB)
# Requirement already satisfied: matplotlib in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from catboost) (3.6.3)
# Requirement already satisfied: numpy>=1.16.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from catboost) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from pandas>=0.24.0->catboost) (2022.7.1)
# Requirement already satisfied: packaging>=20.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib->catboost) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib->catboost) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib->catboost) (1.0.7)
# Collecting tenacity>=6.2.0
#   Using cached tenacity-8.1.0-py3-none-any.whl (23 kB)
# Installing collected packages: tenacity, graphviz, plotly, catboost
# Successfully installed catboost-1.1.1 graphviz-0.20.1 plotly-5.13.0 tenacity-8.1.0
# Collecting bokeh
#   Using cached bokeh-3.0.3-py3-none-any.whl (16.5 MB)
# Requirement already satisfied: contourpy>=1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from bokeh) (1.0.7)
# Requirement already satisfied: pillow>=7.1.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from bokeh) (9.4.0)
# Requirement already satisfied: numpy>=1.11.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from bokeh) (1.24.1)
# Collecting PyYAML>=3.10
#   Using cached PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
# Collecting Jinja2>=2.9
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Requirement already satisfied: tornado>=5.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from bokeh) (6.2)
# Collecting xyzservices>=2021.09.1
#   Using cached xyzservices-2022.9.0-py3-none-any.whl (55 kB)
# Requirement already satisfied: packaging>=16.8 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from bokeh) (23.0)
# Requirement already satisfied: pandas>=1.2 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from bokeh) (1.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from Jinja2>=2.9->bokeh) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from pandas>=1.2->bokeh) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=1.2->bokeh) (1.16.0)
# Installing collected packages: xyzservices, PyYAML, Jinja2, bokeh
# Successfully installed Jinja2-3.1.2 PyYAML-6.0 bokeh-3.0.3 xyzservices-2022.9.0
# Cloning into 'mlperf-logging'...
# Obtaining file:///tmp/mlperf-logging
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas>=1.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from mlperf-logging==2.1.0) (1.5.3)
# Requirement already satisfied: pyyaml>=5.4.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from mlperf-logging==2.1.0) (6.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from mlperf-logging==2.1.0) (1.24.1)
# Requirement already satisfied: scipy>=1.4.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from mlperf-logging==2.1.0) (1.10.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from pandas>=1.0->mlperf-logging==2.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from pandas>=1.0->mlperf-logging==2.1.0) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=1.0->mlperf-logging==2.1.0) (1.16.0)
# Installing collected packages: mlperf-logging
#   Running setup.py develop for mlperf-logging
# Successfully installed mlperf-logging-2.1.0
# Requirement already satisfied: tensorboard in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (2.11.2)
# Requirement already satisfied: grpcio>=1.24.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorboard) (1.51.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorboard) (3.4.1)
# Requirement already satisfied: wheel>=0.26 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorboard) (0.37.1)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: numpy>=1.12.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorboard) (1.24.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorboard) (2.16.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorboard) (2.28.2)
# Requirement already satisfied: absl-py>=0.4 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorboard) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorboard) (2.2.2)
# Requirement already satisfied: setuptools>=41.0.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorboard) (65.6.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard) (6.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard) (3.12.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.2.2)
# Collecting jupyter
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: ipywidgets in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter) (8.0.4)
# Collecting notebook
#   Using cached notebook-6.5.2-py3-none-any.whl (439 kB)
# Collecting nbconvert
#   Using cached nbconvert-7.2.9-py3-none-any.whl (274 kB)
# Collecting qtconsole
#   Using cached qtconsole-5.4.0-py3-none-any.whl (121 kB)
# Collecting jupyter-console
#   Using cached jupyter_console-6.4.4-py3-none-any.whl (22 kB)
# Requirement already satisfied: ipykernel in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter) (6.21.1)
# Requirement already satisfied: nest-asyncio in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->jupyter) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->jupyter) (8.0.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->jupyter) (5.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->jupyter) (8.9.0)
# Requirement already satisfied: tornado>=6.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->jupyter) (6.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->jupyter) (25.0.0)
# Requirement already satisfied: packaging in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->jupyter) (23.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->jupyter) (1.6.6)
# Requirement already satisfied: psutil in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->jupyter) (5.9.4)
# Requirement already satisfied: comm>=0.1.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->jupyter) (0.1.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipywidgets->jupyter) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipywidgets->jupyter) (3.0.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter-console->jupyter) (3.0.36)
# Requirement already satisfied: pygments in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter-console->jupyter) (2.14.0)
# Collecting mistune<3,>=2.0.3
#   Using cached mistune-2.0.4-py2.py3-none-any.whl (24 kB)
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Requirement already satisfied: markupsafe>=2.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbconvert->jupyter) (2.1.2)
# Collecting bleach
#   Using cached bleach-6.0.0-py3-none-any.whl (162 kB)
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: jinja2>=3.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: importlib-metadata>=3.6 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbconvert->jupyter) (6.0.0)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
# Collecting nbformat>=5.1
#   Using cached nbformat-5.7.3-py3-none-any.whl (78 kB)
# Collecting nbclient>=0.5.0
#   Using cached nbclient-0.7.2-py3-none-any.whl (71 kB)
# Collecting tinycss2
#   Using cached tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting Send2Trash>=1.8.0
#   Using cached Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Collecting terminado>=0.8.3
#   Using cached terminado-0.17.1-py3-none-any.whl (17 kB)
# Collecting nbclassic>=0.4.7
#   Using cached nbclassic-0.5.1-py3-none-any.whl (10.0 MB)
# Collecting prometheus-client
#   Using cached prometheus_client-0.16.0-py3-none-any.whl (122 kB)
# Requirement already satisfied: ipython-genutils in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook->jupyter) (0.2.0)
# Collecting argon2-cffi
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting qtpy>=2.0.1
#   Using cached QtPy-2.3.0-py3-none-any.whl (83 kB)
# Requirement already satisfied: zipp>=0.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from importlib-metadata>=3.6->nbconvert->jupyter) (3.12.0)
# Requirement already satisfied: pexpect>4.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.18.2)
# Requirement already satisfied: pickleshare in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: backcall in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: stack-data in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.2)
# Requirement already satisfied: decorator in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (2.6.2)
# Collecting jupyter-server>=1.17.0
#   Using cached jupyter_server-2.2.1-py3-none-any.whl (365 kB)
# Collecting notebook-shim>=0.1.0
#   Using cached notebook_shim-0.2.2-py3-none-any.whl (13 kB)
# Collecting fastjsonschema
#   Using cached fastjsonschema-2.16.2-py3-none-any.whl (22 kB)
# Collecting jsonschema>=2.6
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Requirement already satisfied: wcwidth in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter) (0.2.6)
# Requirement already satisfied: ptyprocess in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from terminado>=0.8.3->notebook->jupyter) (0.7.0)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: six>=1.9.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from bleach->nbconvert->jupyter) (1.16.0)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Collecting importlib-resources>=1.4.0
#   Using cached importlib_resources-5.10.2-py3-none-any.whl (34 kB)
# Collecting pkgutil-resolve-name>=1.3.10
#   Using cached pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Using cached pyrsistent-0.19.3-py3-none-any.whl (57 kB)
# Collecting attrs>=17.4.0
#   Using cached attrs-22.2.0-py3-none-any.whl (60 kB)
# Collecting jupyter-events>=0.4.0
#   Using cached jupyter_events-0.6.3-py3-none-any.whl (18 kB)
# Collecting anyio>=3.1.0
#   Using cached anyio-3.6.2-py3-none-any.whl (80 kB)
# Collecting websocket-client
#   Using cached websocket_client-1.5.1-py3-none-any.whl (55 kB)
# Collecting jupyter-server-terminals
#   Using cached jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting cffi>=1.0.1
#   Using cached cffi-1.15.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
# Requirement already satisfied: executing>=1.2.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: pure-eval in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna>=2.8 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook->jupyter) (3.4)
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting rfc3986-validator>=0.1.1
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting python-json-logger>=2.0.4
#   Using cached python_json_logger-2.0.4-py3-none-any.whl (7.8 kB)
# Collecting rfc3339-validator
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Requirement already satisfied: pyyaml>=5.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook->jupyter) (6.0)
# Collecting webcolors>=1.11
#   Using cached webcolors-1.12-py3-none-any.whl (9.9 kB)
# Collecting jsonpointer>1.13
#   Using cached jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Collecting isoduration
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template
#   Using cached uri_template-1.2.0-py3-none-any.whl (10 kB)
# Collecting fqdn
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting arrow>=0.15.0
#   Using cached arrow-1.2.3-py3-none-any.whl (66 kB)
# Installing collected packages: webencodings, Send2Trash, mistune, fastjsonschema, websocket-client, webcolors, uri-template, tinycss2, terminado, soupsieve, sniffio, rfc3986-validator, rfc3339-validator, qtpy, python-json-logger, pyrsistent, pycparser, prometheus-client, pkgutil-resolve-name, pandocfilters, jupyterlab-pygments, jsonpointer, importlib-resources, fqdn, defusedxml, bleach, attrs, jupyter-server-terminals, jsonschema, cffi, beautifulsoup4, arrow, anyio, nbformat, isoduration, argon2-cffi-bindings, nbclient, argon2-cffi, qtconsole, nbconvert, jupyter-events, jupyter-console, jupyter-server, notebook-shim, nbclassic, notebook, jupyter
# Successfully installed Send2Trash-1.8.0 anyio-3.6.2 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 arrow-1.2.3 attrs-22.2.0 beautifulsoup4-4.11.2 bleach-6.0.0 cffi-1.15.1 defusedxml-0.7.1 fastjsonschema-2.16.2 fqdn-1.5.1 importlib-resources-5.10.2 isoduration-20.11.0 jsonpointer-2.3 jsonschema-4.17.3 jupyter-1.0.0 jupyter-console-6.4.4 jupyter-events-0.6.3 jupyter-server-2.2.1 jupyter-server-terminals-0.4.4 jupyterlab-pygments-0.2.2 mistune-2.0.4 nbclassic-0.5.1 nbclient-0.7.2 nbconvert-7.2.9 nbformat-5.7.3 notebook-6.5.2 notebook-shim-0.2.2 pandocfilters-1.5.0 pkgutil-resolve-name-1.3.10 prometheus-client-0.16.0 pycparser-2.21 pyrsistent-0.19.3 python-json-logger-2.0.4 qtconsole-5.4.0 qtpy-2.3.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 sniffio-1.3.0 soupsieve-2.3.2.post1 terminado-0.17.1 tinycss2-1.2.1 uri-template-1.2.0 webcolors-1.12 webencodings-0.5.1 websocket-client-1.5.1
# Collecting jupyterlab
#   Using cached jupyterlab-3.6.1-py3-none-any.whl (8.9 MB)
# Requirement already satisfied: packaging in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyterlab) (23.0)
# Requirement already satisfied: nbclassic in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyterlab) (0.5.1)
# Requirement already satisfied: tornado>=6.1.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyterlab) (6.2)
# Collecting jupyterlab-server~=2.19
#   Using cached jupyterlab_server-2.19.0-py3-none-any.whl (56 kB)
# Collecting jupyter-server-ydoc<0.7.0,>=0.6.0
#   Using cached jupyter_server_ydoc-0.6.1-py3-none-any.whl (11 kB)
# Collecting jupyter-ydoc~=0.2.2
#   Using cached jupyter_ydoc-0.2.2-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyterlab) (2.2.1)
# ...
# Requirement already satisfied: matplotlib>=1.4.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyterthemes) (3.6.3)
# Requirement already satisfied: lesscpy>=0.11.2 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyterthemes) (0.15.1)
# Requirement already satisfied: matplotlib-inline in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.6)
# Requirement already satisfied: pickleshare in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (4.8.0)
# Requirement already satisfied: backcall in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.18.2)
# Requirement already satisfied: stack-data in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (5.9.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (2.14.0)
# Requirement already satisfied: decorator in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: ply in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from lesscpy>=0.11.2->jupyterthemes) (3.11)
# Requirement already satisfied: python-dateutil>=2.7 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.9)
# Requirement already satisfied: numpy>=1.19 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.24.1)
# Requirement already satisfied: cycler>=0.10 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (4.38.0)
# Requirement already satisfied: pyzmq>=17 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (25.0.0)
# Requirement already satisfied: nbformat in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (5.7.3)
# Requirement already satisfied: nbclassic>=0.4.7 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: tornado>=6.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (6.2)
# Requirement already satisfied: prometheus-client in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (0.16.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (1.5.6)
# Requirement already satisfied: jupyter-client>=5.3.4 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (8.0.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: ipykernel in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (6.21.1)
# Requirement already satisfied: nbconvert>=5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (7.2.9)
# Requirement already satisfied: terminado>=0.8.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (0.17.1)
# Requirement already satisfied: argon2-cffi in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (21.3.0)
# Requirement already satisfied: ipython-genutils in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: jinja2 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (3.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter-core->jupyterthemes) (2.6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook>=5.6.0->jupyterthemes) (6.0.0)
# Requirement already satisfied: jupyter-server>=1.8 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (2.2.1)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.2.2)
# Requirement already satisfied: defusedxml in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: markupsafe>=2.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (2.1.2)
# Requirement already satisfied: bleach in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (6.0.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.7.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.11.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (2.0.4)
# Requirement already satisfied: jupyterlab-pygments in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.2.2)
# Requirement already satisfied: fastjsonschema in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (4.17.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.4.1->jupyterthemes) (0.7.0)
# Requirement already satisfied: wcwidth in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=5.4.1->jupyterthemes) (0.2.6)
# Requirement already satisfied: six>=1.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->jupyterthemes) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (1.6.6)
# Requirement already satisfied: psutil in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (5.9.4)
# Requirement already satisfied: comm>=0.1.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (0.1.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (1.2.0)
# Requirement already satisfied: pure-eval in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.2.2)
# Requirement already satisfied: zipp>=0.5 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=5.3.4->notebook>=5.6.0->jupyterthemes) (3.12.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (5.10.2)
# Requirement already satisfied: attrs>=17.4.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.19.3)
# Requirement already satisfied: anyio>=3.1.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (3.6.2)
# Requirement already satisfied: jupyter-server-terminals in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.4.4)
# Requirement already satisfied: jupyter-events>=0.4.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.5.0)
# Requirement already satisfied: websocket-client in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.5.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from bleach->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (3.4)
# Requirement already satisfied: pycparser in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.21)
# Requirement already satisfied: pyyaml in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (6.0)
# Requirement already satisfied: python-json-logger in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (2.0.4)
# Requirement already satisfied: jsonpointer>1.13 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (2.3)
# Requirement already satisfied: isoduration in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (20.11.0)
# Requirement already satisfied: fqdn in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (1.5.1)
# Requirement already satisfied: rfc3986-validator>0.1.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.1.1)
# Requirement already satisfied: webcolors>=1.11 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (1.12)
# Requirement already satisfied: rfc3339-validator in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.1.4)
# Requirement already satisfied: uri-template in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (1.2.0)
# Requirement already satisfied: arrow>=0.15.0 in /home/cc/anaconda3/envs/flashnet-trovi-env/lib/python3.8/site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (1.2.3)
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# Install ipykernel
eval "$ssh_command" /bin/bash << EOF
    cd flashnet-trovi
    source ~/.zshrc
    which conda
    conda install -n flashnet-trovi-env ipykernel --update-deps --force-reinstall -y
EOF
# Out:
# /home/cc/anaconda3/condabin/conda
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... Solving environment: ...working... done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/cc/anaconda3/envs/flashnet-trovi-env
#
#   added / updated specs:
#     - _libgcc_mutex
#     - _openmp_mutex
#     - asttokens
#     - backcall
#     - ca-certificates
#     - certifi
#     - comm
#     - debugpy
#     - decorator
#     - entrypoints
#     - executing
#     - ipykernel
#     - ipython
#     - jedi
#     - jupyter_client
#     - jupyter_core
#     - ld_impl_linux-64
#     - libffi
#     - libgcc-ng
#     - libgomp
#     - libsodium
#     - libstdcxx-ng
#     - matplotlib-inline
#     - ncurses
#     - nest-asyncio
#     - openssl
#     - packaging
#     - parso
#     - pexpect
#     - pickleshare
#     - pip
#     - platformdirs
#     - prompt-toolkit
#     - psutil
#     - ptyprocess
#     - pure_eval
#     - pygments
#     - python-dateutil
#     - python=3.8
#     - pyzmq
#     - readline
#     - setuptools
#     - six
#     - sqlite
#     - stack_data
#     - tk
#     - tornado
#     - traitlets
#     - wcwidth
#     - wheel
#     - xz
#     - zeromq
#     - zlib
#
#
# The following NEW packages will be INSTALLED:
#
#   asttokens          pkgs/main/noarch::asttokens-2.0.5-pyhd3eb1b0_0 None
#   backcall           pkgs/main/noarch::backcall-0.2.0-pyhd3eb1b0_0 None
#   comm               pkgs/main/linux-64::comm-0.1.2-py38h06a4308_0 None
#   debugpy            pkgs/main/linux-64::debugpy-1.5.1-py38h295c915_0 None
#   decorator          pkgs/main/noarch::decorator-5.1.1-pyhd3eb1b0_0 None
#   entrypoints        pkgs/main/linux-64::entrypoints-0.4-py38h06a4308_0 None
#   executing          pkgs/main/noarch::executing-0.8.3-pyhd3eb1b0_0 None
#   ipykernel          pkgs/main/linux-64::ipykernel-6.19.2-py38hb070fc8_0 None
#   ipython            pkgs/main/linux-64::ipython-8.8.0-py38h06a4308_0 None
#   jedi               pkgs/main/linux-64::jedi-0.18.1-py38h06a4308_1 None
#   jupyter_client     pkgs/main/linux-64::jupyter_client-7.4.8-py38h06a4308_0 None
#   jupyter_core       pkgs/main/linux-64::jupyter_core-5.1.1-py38h06a4308_0 None
#   libsodium          pkgs/main/linux-64::libsodium-1.0.18-h7b6447c_0 None
#   matplotlib-inline  pkgs/main/linux-64::matplotlib-inline-0.1.6-py38h06a4308_0 None
#   nest-asyncio       pkgs/main/linux-64::nest-asyncio-1.5.6-py38h06a4308_0 None
#   packaging          pkgs/main/linux-64::packaging-22.0-py38h06a4308_0 None
#   parso              pkgs/main/noarch::parso-0.8.3-pyhd3eb1b0_0 None
#   pexpect            pkgs/main/noarch::pexpect-4.8.0-pyhd3eb1b0_3 None
#   pickleshare        pkgs/main/noarch::pickleshare-0.7.5-pyhd3eb1b0_1003 None
#   platformdirs       pkgs/main/linux-64::platformdirs-2.5.2-py38h06a4308_0 None
#   prompt-toolkit     pkgs/main/linux-64::prompt-toolkit-3.0.36-py38h06a4308_0 None
#   psutil             pkgs/main/linux-64::psutil-5.9.0-py38h5eee18b_0 None
#   ptyprocess         pkgs/main/noarch::ptyprocess-0.7.0-pyhd3eb1b0_2 None
#   pure_eval          pkgs/main/noarch::pure_eval-0.2.2-pyhd3eb1b0_0 None
#   pygments           pkgs/main/noarch::pygments-2.11.2-pyhd3eb1b0_0 None
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.2-pyhd3eb1b0_0 None
#   pyzmq              pkgs/main/linux-64::pyzmq-23.2.0-py38h6a678d5_0 None
#   six                pkgs/main/noarch::six-1.16.0-pyhd3eb1b0_1 None
#   stack_data         pkgs/main/noarch::stack_data-0.2.0-pyhd3eb1b0_0 None
#   tornado            pkgs/main/linux-64::tornado-6.2-py38h5eee18b_0 None
#   traitlets          pkgs/main/linux-64::traitlets-5.7.1-py38h06a4308_0 None
#   wcwidth            pkgs/main/noarch::wcwidth-0.2.5-pyhd3eb1b0_0 None
#   zeromq             pkgs/main/linux-64::zeromq-4.3.4-h2531618_0 None
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done

# %%
FLASHNET=`eval "$ssh_command" /bin/bash << EOF
    cd flashnet-trovi
    pwd
EOF`
export FLASHNET=$FLASHNET

# %%
eval "$ssh_command" /bin/bash << EOF
    export FLASHNET=$FLASHNET
EOF

# %% [markdown]
# ### 1. Run Tail Analyzer for Labeling

# %%
eval "$ssh_command" /bin/bash << EOF
    source ~/.zshrc
    cd $FLASHNET/model_collection/1_per_io_admission/tail_analyzer/
    conda activate "flashnet-trovi-env" && ./tail_v2.py -files $FLASHNET/data/trace_profile/nvme0n1/tencent.cut.per_50k*.trace
EOF
# Out:
# trace_profiles = ['/home/cc/flashnet-trovi/data/trace_profile/nvme0n1/tencent.cut.per_50k.most_rand_iops.537.trace', '/home/cc/flashnet-trovi/data/trace_profile/nvme0n1/tencent.cut.per_50k.most_size_thpt.222.trace', '/home/cc/flashnet-trovi/data/trace_profile/nvme0n1/tencent.cut.per_50k.rw_60_40.490.trace', '/home/cc/flashnet-trovi/data/trace_profile/nvme0n1/tencent.cut.per_50k.rw_65_35.211.trace', '/home/cc/flashnet-trovi/data/trace_profile/nvme0n1/tencent.cut.per_50k.rw_75_25.379.trace']
#
# Processing /home/cc/flashnet-trovi/data/trace_profile/nvme0n1/tencent.cut.per_50k.most_rand_iops.537.trace
# #IO labeled = 50000
# Fast IO = 36216
# Slow IO = 13784
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.labeled
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.lat_cdf.png
#
# Processing /home/cc/flashnet-trovi/data/trace_profile/nvme0n1/tencent.cut.per_50k.most_size_thpt.222.trace
# #IO labeled = 50000
# Fast IO = 38215
# Slow IO = 11785
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.labeled
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.lat_cdf.png
#
# Processing /home/cc/flashnet-trovi/data/trace_profile/nvme0n1/tencent.cut.per_50k.rw_60_40.490.trace
# #IO labeled = 50000
# Fast IO = 34266
# Slow IO = 15734
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.labeled
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.lat_cdf.png
#
# Processing /home/cc/flashnet-trovi/data/trace_profile/nvme0n1/tencent.cut.per_50k.rw_65_35.211.trace
# #IO labeled = 50000
# Fast IO = 34395
# Slow IO = 15605
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.labeled
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.lat_cdf.png
#
# Processing /home/cc/flashnet-trovi/data/trace_profile/nvme0n1/tencent.cut.per_50k.rw_75_25.379.trace
# #IO labeled = 50000
# Fast IO = 36260
# Slow IO = 13740
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.labeled
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.lat_cdf.png

# %% [markdown]
# ### 2. Run Feature Extractor

# %%
# run on multiple profiles
eval "$ssh_command" /bin/bash << EOF
    source ~/.zshrc
    cd $FLASHNET/model_collection/1_per_io_admission/feature_extractor/
    conda activate flashnet-trovi-env && ./feat_v2.py -files ../dataset/nvme0n1/tencent.cut.per_50k*/profile_v2.labeled
EOF
# Out:
# trace_profiles = ['../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.labeled', '../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.labeled', '../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.labeled', '../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.labeled', '../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.labeled']
#
# Processing ../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.labeled
# Removed 3 first IOs because they don't have enough historical data
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.feat_v2.dataset
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.feat_v2.readonly.dataset
#
# Processing ../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.labeled
# Removed 3 first IOs because they don't have enough historical data
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.feat_v2.dataset
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.feat_v2.readonly.dataset
#
# Processing ../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.labeled
# Removed 3 first IOs because they don't have enough historical data
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.feat_v2.dataset
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.feat_v2.readonly.dataset
#
# Processing ../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.labeled
# Removed 3 first IOs because they don't have enough historical data
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.feat_v2.dataset
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.feat_v2.readonly.dataset
#
# Processing ../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.labeled
# Removed 3 first IOs because they don't have enough historical data
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.feat_v2.dataset
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.feat_v2.readonly.dataset

# %% [markdown]
# ### 3. Train the NN model

# %%
# train on multiple datasets
eval "$ssh_command" /bin/bash << EOF
    source ~/.zshrc
    cd $FLASHNET/model_collection/1_per_io_admission/train/
    conda activate flashnet-trovi-env && ./train_and_eval.py -model model_binary_nn -datasets ../dataset/nvme0n1/tencent*cut*per*/profile*feat*.dataset -train_eval_split 50_50
EOF
# Out:
# 2023-02-05 15:39:34.860515: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-05 15:39:34.860542: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-05 15:39:36.249793: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-05 15:39:36.249820: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rani-flashnet4): /proc/driver/nvidia/version does not exist
# 2023-02-05 15:39:36.250051: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [[8.2122582e-01 9.2154316e+03 1.4032305e+03 1.4001462e+03 1.4026096e+03
#   2.8238577e+01 2.8158209e+01 2.7460609e+01]]
# Epoch 1/20
# 625/625 [==============================] - 4s 5ms/step - loss: 0.3097 - accuracy: 0.8923 - val_loss: 0.2559 - val_accuracy: 0.9044
# Epoch 2/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2620 - accuracy: 0.8968 - val_loss: 0.2440 - val_accuracy: 0.9070
# Epoch 3/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2535 - accuracy: 0.8992 - val_loss: 0.2377 - val_accuracy: 0.9070
# Epoch 4/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2486 - accuracy: 0.9007 - val_loss: 0.2350 - val_accuracy: 0.9076
# Epoch 5/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2443 - accuracy: 0.9020 - val_loss: 0.2321 - val_accuracy: 0.9094
# Epoch 6/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2419 - accuracy: 0.9021 - val_loss: 0.2334 - val_accuracy: 0.9090
# Epoch 7/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2392 - accuracy: 0.9046 - val_loss: 0.2303 - val_accuracy: 0.9120
# Epoch 8/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2382 - accuracy: 0.9057 - val_loss: 0.2285 - val_accuracy: 0.9110
# Epoch 9/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2364 - accuracy: 0.9060 - val_loss: 0.2282 - val_accuracy: 0.9128
# Epoch 10/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2355 - accuracy: 0.9065 - val_loss: 0.2263 - val_accuracy: 0.9106
# Epoch 11/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2338 - accuracy: 0.9071 - val_loss: 0.2276 - val_accuracy: 0.9100
# Epoch 12/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2330 - accuracy: 0.9076 - val_loss: 0.2274 - val_accuracy: 0.9110
# Epoch 13/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2325 - accuracy: 0.9078 - val_loss: 0.2244 - val_accuracy: 0.9120
# Epoch 14/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2317 - accuracy: 0.9085 - val_loss: 0.2248 - val_accuracy: 0.9122
# Epoch 15/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2309 - accuracy: 0.9092 - val_loss: 0.2238 - val_accuracy: 0.9144
# Epoch 16/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2305 - accuracy: 0.9110 - val_loss: 0.2237 - val_accuracy: 0.9138
# Epoch 17/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2298 - accuracy: 0.9099 - val_loss: 0.2254 - val_accuracy: 0.9138
# Epoch 18/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2293 - accuracy: 0.9100 - val_loss: 0.2256 - val_accuracy: 0.9130
# Epoch 19/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2288 - accuracy: 0.9108 - val_loss: 0.2224 - val_accuracy: 0.9130
# Epoch 20/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2279 - accuracy: 0.9113 - val_loss: 0.2261 - val_accuracy: 0.9132
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.feat_v2/model_binary_nn/eval.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.feat_v2/model_binary_nn/eval.png
# 2023-02-05 15:40:42.998977: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-05 15:40:42.999004: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-05 15:40:44.383123: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-05 15:40:44.383151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rani-flashnet4): /proc/driver/nvidia/version does not exist
# 2023-02-05 15:40:44.383381: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [[1.00000000e+00 8.65139453e+03 1.55035022e+03 1.54121460e+03
#   1.53899670e+03 1.40773945e+01 1.56729841e+01 1.61304436e+01]]
# Epoch 1/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.3562 - accuracy: 0.8716 - val_loss: 0.3196 - val_accuracy: 0.8777
# Epoch 2/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.3085 - accuracy: 0.8788 - val_loss: 0.3118 - val_accuracy: 0.8779
# Epoch 3/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.3010 - accuracy: 0.8800 - val_loss: 0.3040 - val_accuracy: 0.8811
# Epoch 4/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.2943 - accuracy: 0.8806 - val_loss: 0.3002 - val_accuracy: 0.8830
# Epoch 5/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.2893 - accuracy: 0.8859 - val_loss: 0.2972 - val_accuracy: 0.8852
# Epoch 6/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.2854 - accuracy: 0.8858 - val_loss: 0.2925 - val_accuracy: 0.8869
# Epoch 7/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.2823 - accuracy: 0.8887 - val_loss: 0.2904 - val_accuracy: 0.8855
# Epoch 8/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.2795 - accuracy: 0.8900 - val_loss: 0.2887 - val_accuracy: 0.8847
# Epoch 9/20
# 513/513 [==============================] - 2s 5ms/step - loss: 0.2773 - accuracy: 0.8888 - val_loss: 0.2904 - val_accuracy: 0.8813
# Epoch 10/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.2760 - accuracy: 0.8917 - val_loss: 0.2887 - val_accuracy: 0.8830
# Epoch 11/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.2740 - accuracy: 0.8912 - val_loss: 0.2874 - val_accuracy: 0.8882
# Epoch 12/20
# 513/513 [==============================] - 2s 5ms/step - loss: 0.2734 - accuracy: 0.8911 - val_loss: 0.2857 - val_accuracy: 0.8857
# Epoch 13/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.2719 - accuracy: 0.8925 - val_loss: 0.2848 - val_accuracy: 0.8823
# Epoch 14/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.2707 - accuracy: 0.8937 - val_loss: 0.2876 - val_accuracy: 0.8799
# Epoch 15/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.2702 - accuracy: 0.8923 - val_loss: 0.2841 - val_accuracy: 0.8874
# Epoch 16/20
# 513/513 [==============================] - 2s 5ms/step - loss: 0.2690 - accuracy: 0.8950 - val_loss: 0.2831 - val_accuracy: 0.8874
# Epoch 17/20
# 513/513 [==============================] - 2s 5ms/step - loss: 0.2684 - accuracy: 0.8942 - val_loss: 0.2829 - val_accuracy: 0.8850
# Epoch 18/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.2678 - accuracy: 0.8942 - val_loss: 0.2843 - val_accuracy: 0.8855
# Epoch 19/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.2676 - accuracy: 0.8949 - val_loss: 0.2820 - val_accuracy: 0.8845
# Epoch 20/20
# 513/513 [==============================] - 3s 5ms/step - loss: 0.2660 - accuracy: 0.8953 - val_loss: 0.2815 - val_accuracy: 0.8855
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.feat_v2.readonly/model_binary_nn/eval.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.feat_v2.readonly/model_binary_nn/eval.png
# 2023-02-05 15:41:39.625083: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-05 15:41:39.625111: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-05 15:41:41.010143: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-05 15:41:41.010171: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rani-flashnet4): /proc/driver/nvidia/version does not exist
# 2023-02-05 15:41:41.010402: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [[8.31826389e-01 2.56538047e+04 1.91917346e+03 1.91786145e+03
#   1.92158630e+03 1.59858665e+01 1.56592913e+01 1.56299715e+01]]
# Epoch 1/20
# 625/625 [==============================] - 4s 5ms/step - loss: 0.2624 - accuracy: 0.9082 - val_loss: 0.2133 - val_accuracy: 0.9162
# Epoch 2/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2090 - accuracy: 0.9198 - val_loss: 0.2001 - val_accuracy: 0.9220
# Epoch 3/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2011 - accuracy: 0.9232 - val_loss: 0.1966 - val_accuracy: 0.9222
# Epoch 4/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1979 - accuracy: 0.9235 - val_loss: 0.1950 - val_accuracy: 0.9222
# Epoch 5/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1956 - accuracy: 0.9251 - val_loss: 0.1947 - val_accuracy: 0.9226
# Epoch 6/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1940 - accuracy: 0.9238 - val_loss: 0.1926 - val_accuracy: 0.9206
# Epoch 7/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1924 - accuracy: 0.9255 - val_loss: 0.1892 - val_accuracy: 0.9234
# Epoch 8/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1909 - accuracy: 0.9262 - val_loss: 0.1880 - val_accuracy: 0.9232
# Epoch 9/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1898 - accuracy: 0.9262 - val_loss: 0.1876 - val_accuracy: 0.9216
# Epoch 10/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1887 - accuracy: 0.9261 - val_loss: 0.1868 - val_accuracy: 0.9236
# Epoch 11/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1882 - accuracy: 0.9266 - val_loss: 0.1849 - val_accuracy: 0.9244
# Epoch 12/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1871 - accuracy: 0.9273 - val_loss: 0.1864 - val_accuracy: 0.9242
# Epoch 13/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1864 - accuracy: 0.9270 - val_loss: 0.1865 - val_accuracy: 0.9226
# Epoch 14/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1858 - accuracy: 0.9276 - val_loss: 0.1837 - val_accuracy: 0.9234
# Epoch 15/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1854 - accuracy: 0.9279 - val_loss: 0.1832 - val_accuracy: 0.9250
# Epoch 16/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1846 - accuracy: 0.9273 - val_loss: 0.1848 - val_accuracy: 0.9244
# Epoch 17/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1840 - accuracy: 0.9285 - val_loss: 0.1835 - val_accuracy: 0.9238
# Epoch 18/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1837 - accuracy: 0.9281 - val_loss: 0.1828 - val_accuracy: 0.9270
# Epoch 19/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1836 - accuracy: 0.9273 - val_loss: 0.1826 - val_accuracy: 0.9262
# Epoch 20/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1830 - accuracy: 0.9284 - val_loss: 0.1824 - val_accuracy: 0.9248
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.feat_v2/model_binary_nn/eval.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.feat_v2/model_binary_nn/eval.png
# 2023-02-05 15:42:47.807859: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-05 15:42:47.807888: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-05 15:42:49.189784: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-05 15:42:49.189812: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rani-flashnet4): /proc/driver/nvidia/version does not exist
# 2023-02-05 15:42:49.190038: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [[1.0000000e+00 2.9571211e+04 2.1310269e+03 2.1247959e+03 2.1238579e+03
#   1.5582695e+01 1.5502524e+01 1.5549119e+01]]
# Epoch 1/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2910 - accuracy: 0.8917 - val_loss: 0.2519 - val_accuracy: 0.8977
# Epoch 2/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2425 - accuracy: 0.9078 - val_loss: 0.2467 - val_accuracy: 0.9011
# Epoch 3/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2363 - accuracy: 0.9079 - val_loss: 0.2402 - val_accuracy: 0.9059
# Epoch 4/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2336 - accuracy: 0.9086 - val_loss: 0.2424 - val_accuracy: 0.9068
# Epoch 5/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2310 - accuracy: 0.9104 - val_loss: 0.2390 - val_accuracy: 0.9037
# Epoch 6/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2292 - accuracy: 0.9102 - val_loss: 0.2381 - val_accuracy: 0.9037
# Epoch 7/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2279 - accuracy: 0.9097 - val_loss: 0.2354 - val_accuracy: 0.9068
# Epoch 8/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2261 - accuracy: 0.9109 - val_loss: 0.2338 - val_accuracy: 0.9085
# Epoch 9/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2248 - accuracy: 0.9096 - val_loss: 0.2332 - val_accuracy: 0.9075
# Epoch 10/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2234 - accuracy: 0.9120 - val_loss: 0.2327 - val_accuracy: 0.9080
# Epoch 11/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2224 - accuracy: 0.9113 - val_loss: 0.2313 - val_accuracy: 0.9083
# Epoch 12/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2215 - accuracy: 0.9112 - val_loss: 0.2305 - val_accuracy: 0.9083
# Epoch 13/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2201 - accuracy: 0.9118 - val_loss: 0.2323 - val_accuracy: 0.9071
# Epoch 14/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2186 - accuracy: 0.9116 - val_loss: 0.2296 - val_accuracy: 0.9068
# Epoch 15/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2190 - accuracy: 0.9120 - val_loss: 0.2319 - val_accuracy: 0.9075
# Epoch 16/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2177 - accuracy: 0.9133 - val_loss: 0.2289 - val_accuracy: 0.9090
# Epoch 17/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2176 - accuracy: 0.9132 - val_loss: 0.2306 - val_accuracy: 0.9090
# Epoch 18/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2164 - accuracy: 0.9145 - val_loss: 0.2315 - val_accuracy: 0.9097
# Epoch 19/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2167 - accuracy: 0.9130 - val_loss: 0.2282 - val_accuracy: 0.9087
# Epoch 20/20
# 521/521 [==============================] - 3s 5ms/step - loss: 0.2158 - accuracy: 0.9141 - val_loss: 0.2290 - val_accuracy: 0.9066
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.feat_v2.readonly/model_binary_nn/eval.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.feat_v2.readonly/model_binary_nn/eval.png
# 2023-02-05 15:43:45.551814: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-05 15:43:45.551843: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-05 15:43:46.939786: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-05 15:43:46.939815: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rani-flashnet4): /proc/driver/nvidia/version does not exist
# 2023-02-05 15:43:46.940031: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [[6.0012865e-01 1.2135454e+04 1.1996090e+03 1.2010928e+03 1.2041250e+03
#   4.1297359e+01 4.1690647e+01 4.1668209e+01]]
# Epoch 1/20
# 625/625 [==============================] - 4s 5ms/step - loss: 0.2946 - accuracy: 0.8844 - val_loss: 0.2536 - val_accuracy: 0.8916
# Epoch 2/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2527 - accuracy: 0.8911 - val_loss: 0.2541 - val_accuracy: 0.8884
# Epoch 3/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2489 - accuracy: 0.8917 - val_loss: 0.2477 - val_accuracy: 0.8910
# Epoch 4/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2467 - accuracy: 0.8919 - val_loss: 0.2454 - val_accuracy: 0.8934
# Epoch 5/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2445 - accuracy: 0.8933 - val_loss: 0.2442 - val_accuracy: 0.8938
# Epoch 6/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2432 - accuracy: 0.8934 - val_loss: 0.2441 - val_accuracy: 0.8946
# Epoch 7/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2419 - accuracy: 0.8946 - val_loss: 0.2436 - val_accuracy: 0.8964
# Epoch 8/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2406 - accuracy: 0.8953 - val_loss: 0.2438 - val_accuracy: 0.8974
# Epoch 9/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2398 - accuracy: 0.8953 - val_loss: 0.2420 - val_accuracy: 0.8958
# Epoch 10/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2386 - accuracy: 0.8958 - val_loss: 0.2405 - val_accuracy: 0.8970
# Epoch 11/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2381 - accuracy: 0.8962 - val_loss: 0.2385 - val_accuracy: 0.8952
# Epoch 12/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2369 - accuracy: 0.8969 - val_loss: 0.2386 - val_accuracy: 0.8960
# Epoch 13/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2367 - accuracy: 0.8981 - val_loss: 0.2395 - val_accuracy: 0.8966
# Epoch 14/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2357 - accuracy: 0.8959 - val_loss: 0.2380 - val_accuracy: 0.8936
# Epoch 15/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2351 - accuracy: 0.8969 - val_loss: 0.2387 - val_accuracy: 0.8940
# Epoch 16/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2345 - accuracy: 0.8977 - val_loss: 0.2378 - val_accuracy: 0.8946
# Epoch 17/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2339 - accuracy: 0.8977 - val_loss: 0.2370 - val_accuracy: 0.8934
# Epoch 18/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2336 - accuracy: 0.8982 - val_loss: 0.2357 - val_accuracy: 0.8954
# Epoch 19/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2337 - accuracy: 0.8977 - val_loss: 0.2361 - val_accuracy: 0.8974
# Epoch 20/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2328 - accuracy: 0.8988 - val_loss: 0.2363 - val_accuracy: 0.8964
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.feat_v2/model_binary_nn/eval.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.feat_v2/model_binary_nn/eval.png
# 2023-02-05 15:44:54.379285: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-05 15:44:54.379312: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-05 15:44:55.748598: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-05 15:44:55.748626: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rani-flashnet4): /proc/driver/nvidia/version does not exist
# 2023-02-05 15:44:55.748849: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [[1.0000000e+00 1.1951129e+04 1.6033530e+03 1.5920044e+03 1.5681174e+03
#   1.1676747e+01 1.5243935e+01 1.5015527e+01]]
# Epoch 1/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.4612 - accuracy: 0.8080 - val_loss: 0.4333 - val_accuracy: 0.8167
# Epoch 2/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.4241 - accuracy: 0.8193 - val_loss: 0.4233 - val_accuracy: 0.8147
# Epoch 3/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.4169 - accuracy: 0.8204 - val_loss: 0.4189 - val_accuracy: 0.8174
# Epoch 4/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.4118 - accuracy: 0.8217 - val_loss: 0.4157 - val_accuracy: 0.8194
# Epoch 5/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.4082 - accuracy: 0.8240 - val_loss: 0.4077 - val_accuracy: 0.8167
# Epoch 6/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.4051 - accuracy: 0.8232 - val_loss: 0.4053 - val_accuracy: 0.8211
# Epoch 7/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.4023 - accuracy: 0.8252 - val_loss: 0.4050 - val_accuracy: 0.8217
# Epoch 8/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.4007 - accuracy: 0.8266 - val_loss: 0.4029 - val_accuracy: 0.8231
# Epoch 9/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.3984 - accuracy: 0.8287 - val_loss: 0.4044 - val_accuracy: 0.8214
# Epoch 10/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.3968 - accuracy: 0.8255 - val_loss: 0.4016 - val_accuracy: 0.8247
# Epoch 11/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.3952 - accuracy: 0.8283 - val_loss: 0.4001 - val_accuracy: 0.8207
# Epoch 12/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.3939 - accuracy: 0.8291 - val_loss: 0.4011 - val_accuracy: 0.8197
# Epoch 13/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.3915 - accuracy: 0.8289 - val_loss: 0.3974 - val_accuracy: 0.8211
# Epoch 14/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.3922 - accuracy: 0.8284 - val_loss: 0.3985 - val_accuracy: 0.8264
# Epoch 15/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.3910 - accuracy: 0.8288 - val_loss: 0.3983 - val_accuracy: 0.8257
# Epoch 16/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.3894 - accuracy: 0.8301 - val_loss: 0.3969 - val_accuracy: 0.8264
# Epoch 17/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.3885 - accuracy: 0.8301 - val_loss: 0.3964 - val_accuracy: 0.8241
# Epoch 18/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.3880 - accuracy: 0.8310 - val_loss: 0.3961 - val_accuracy: 0.8231
# Epoch 19/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.3869 - accuracy: 0.8305 - val_loss: 0.3956 - val_accuracy: 0.8244
# Epoch 20/20
# 376/376 [==============================] - 2s 5ms/step - loss: 0.3861 - accuracy: 0.8316 - val_loss: 0.3937 - val_accuracy: 0.8247
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.feat_v2.readonly/model_binary_nn/eval.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.feat_v2.readonly/model_binary_nn/eval.png
# 2023-02-05 15:45:37.481099: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-05 15:45:37.481127: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-05 15:45:38.849652: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-05 15:45:38.849679: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rani-flashnet4): /proc/driver/nvidia/version does not exist
# 2023-02-05 15:45:38.849908: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [[6.5693301e-01 1.1375179e+04 1.2390829e+03 1.2346439e+03 1.2344220e+03
#   3.9443455e+01 3.9640114e+01 3.9791630e+01]]
# Epoch 1/20
# 625/625 [==============================] - 4s 5ms/step - loss: 0.3037 - accuracy: 0.8821 - val_loss: 0.2690 - val_accuracy: 0.8860
# Epoch 2/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2625 - accuracy: 0.8873 - val_loss: 0.2634 - val_accuracy: 0.8858
# Epoch 3/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2577 - accuracy: 0.8889 - val_loss: 0.2584 - val_accuracy: 0.8916
# Epoch 4/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2538 - accuracy: 0.8900 - val_loss: 0.2564 - val_accuracy: 0.8900
# Epoch 5/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2503 - accuracy: 0.8911 - val_loss: 0.2547 - val_accuracy: 0.8906
# Epoch 6/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2489 - accuracy: 0.8922 - val_loss: 0.2530 - val_accuracy: 0.8906
# Epoch 7/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2470 - accuracy: 0.8923 - val_loss: 0.2503 - val_accuracy: 0.8932
# Epoch 8/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2450 - accuracy: 0.8942 - val_loss: 0.2506 - val_accuracy: 0.8952
# Epoch 9/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2437 - accuracy: 0.8934 - val_loss: 0.2487 - val_accuracy: 0.8946
# Epoch 10/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2424 - accuracy: 0.8952 - val_loss: 0.2487 - val_accuracy: 0.8914
# Epoch 11/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2414 - accuracy: 0.8960 - val_loss: 0.2480 - val_accuracy: 0.8966
# Epoch 12/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2408 - accuracy: 0.8953 - val_loss: 0.2473 - val_accuracy: 0.8942
# Epoch 13/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2403 - accuracy: 0.8957 - val_loss: 0.2489 - val_accuracy: 0.8916
# Epoch 14/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2397 - accuracy: 0.8963 - val_loss: 0.2475 - val_accuracy: 0.8922
# Epoch 15/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2391 - accuracy: 0.8953 - val_loss: 0.2479 - val_accuracy: 0.8964
# Epoch 16/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2389 - accuracy: 0.8969 - val_loss: 0.2477 - val_accuracy: 0.8948
# Epoch 17/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2380 - accuracy: 0.8958 - val_loss: 0.2469 - val_accuracy: 0.8900
# Epoch 18/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2379 - accuracy: 0.8967 - val_loss: 0.2504 - val_accuracy: 0.8902
# Epoch 19/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2368 - accuracy: 0.8971 - val_loss: 0.2467 - val_accuracy: 0.8938
# Epoch 20/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2371 - accuracy: 0.8983 - val_loss: 0.2477 - val_accuracy: 0.8928
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.feat_v2/model_binary_nn/eval.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.feat_v2/model_binary_nn/eval.png
# 2023-02-05 15:46:44.901613: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-05 15:46:44.901638: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-05 15:46:46.269596: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-05 15:46:46.269623: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rani-flashnet4): /proc/driver/nvidia/version does not exist
# 2023-02-05 15:46:46.269854: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [[1.0000000e+00 1.0808831e+04 1.5907959e+03 1.5850159e+03 1.5640159e+03
#   1.1379814e+01 1.5438192e+01 1.5376787e+01]]
# Epoch 1/20
# 412/412 [==============================] - 3s 5ms/step - loss: 0.4399 - accuracy: 0.8274 - val_loss: 0.4167 - val_accuracy: 0.8237
# Epoch 2/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.4022 - accuracy: 0.8334 - val_loss: 0.4086 - val_accuracy: 0.8237
# Epoch 3/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3935 - accuracy: 0.8357 - val_loss: 0.3975 - val_accuracy: 0.8204
# Epoch 4/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3878 - accuracy: 0.8370 - val_loss: 0.3933 - val_accuracy: 0.8219
# Epoch 5/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3822 - accuracy: 0.8395 - val_loss: 0.3913 - val_accuracy: 0.8216
# Epoch 6/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3786 - accuracy: 0.8384 - val_loss: 0.3904 - val_accuracy: 0.8222
# Epoch 7/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3763 - accuracy: 0.8402 - val_loss: 0.3872 - val_accuracy: 0.8237
# Epoch 8/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3741 - accuracy: 0.8409 - val_loss: 0.3839 - val_accuracy: 0.8243
# Epoch 9/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3727 - accuracy: 0.8418 - val_loss: 0.3817 - val_accuracy: 0.8213
# Epoch 10/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3702 - accuracy: 0.8442 - val_loss: 0.3853 - val_accuracy: 0.8265
# Epoch 11/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3685 - accuracy: 0.8442 - val_loss: 0.3839 - val_accuracy: 0.8240
# Epoch 12/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3685 - accuracy: 0.8440 - val_loss: 0.3801 - val_accuracy: 0.8289
# Epoch 13/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3664 - accuracy: 0.8454 - val_loss: 0.3789 - val_accuracy: 0.8243
# Epoch 14/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3658 - accuracy: 0.8460 - val_loss: 0.3808 - val_accuracy: 0.8246
# Epoch 15/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3651 - accuracy: 0.8450 - val_loss: 0.3816 - val_accuracy: 0.8246
# Epoch 16/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3636 - accuracy: 0.8478 - val_loss: 0.3807 - val_accuracy: 0.8234
# Epoch 17/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3628 - accuracy: 0.8457 - val_loss: 0.3769 - val_accuracy: 0.8262
# Epoch 18/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3628 - accuracy: 0.8460 - val_loss: 0.3816 - val_accuracy: 0.8271
# Epoch 19/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3621 - accuracy: 0.8468 - val_loss: 0.3815 - val_accuracy: 0.8246
# Epoch 20/20
# 412/412 [==============================] - 2s 5ms/step - loss: 0.3614 - accuracy: 0.8460 - val_loss: 0.3778 - val_accuracy: 0.8277
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.feat_v2.readonly/model_binary_nn/eval.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.feat_v2.readonly/model_binary_nn/eval.png
# 2023-02-05 15:47:31.859505: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-05 15:47:31.859529: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-05 15:47:33.268370: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-05 15:47:33.268397: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rani-flashnet4): /proc/driver/nvidia/version does not exist
# 2023-02-05 15:47:33.268607: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [[7.5134057e-01 1.2798403e+04 1.4172970e+03 1.4208021e+03 1.4154316e+03
#   3.3448116e+01 3.3381634e+01 3.2819305e+01]]
# Epoch 1/20
# 625/625 [==============================] - 4s 5ms/step - loss: 0.3010 - accuracy: 0.8897 - val_loss: 0.2573 - val_accuracy: 0.9000
# Epoch 2/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2532 - accuracy: 0.8978 - val_loss: 0.2487 - val_accuracy: 0.9006
# Epoch 3/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2463 - accuracy: 0.8992 - val_loss: 0.2431 - val_accuracy: 0.9032
# Epoch 4/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2407 - accuracy: 0.9019 - val_loss: 0.2367 - val_accuracy: 0.9040
# Epoch 5/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2371 - accuracy: 0.9038 - val_loss: 0.2328 - val_accuracy: 0.9062
# Epoch 6/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2343 - accuracy: 0.9054 - val_loss: 0.2315 - val_accuracy: 0.9072
# Epoch 7/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2318 - accuracy: 0.9049 - val_loss: 0.2284 - val_accuracy: 0.9084
# Epoch 8/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2302 - accuracy: 0.9054 - val_loss: 0.2302 - val_accuracy: 0.9092
# Epoch 9/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2288 - accuracy: 0.9066 - val_loss: 0.2268 - val_accuracy: 0.9084
# Epoch 10/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2283 - accuracy: 0.9044 - val_loss: 0.2258 - val_accuracy: 0.9076
# Epoch 11/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2269 - accuracy: 0.9063 - val_loss: 0.2282 - val_accuracy: 0.9078
# Epoch 12/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2259 - accuracy: 0.9084 - val_loss: 0.2278 - val_accuracy: 0.9078
# Epoch 13/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2251 - accuracy: 0.9078 - val_loss: 0.2245 - val_accuracy: 0.9092
# Epoch 14/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2248 - accuracy: 0.9077 - val_loss: 0.2239 - val_accuracy: 0.9096
# Epoch 15/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2245 - accuracy: 0.9073 - val_loss: 0.2257 - val_accuracy: 0.9104
# Epoch 16/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2236 - accuracy: 0.9085 - val_loss: 0.2267 - val_accuracy: 0.9074
# Epoch 17/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2234 - accuracy: 0.9084 - val_loss: 0.2231 - val_accuracy: 0.9114
# Epoch 18/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2227 - accuracy: 0.9089 - val_loss: 0.2232 - val_accuracy: 0.9084
# Epoch 19/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2219 - accuracy: 0.9094 - val_loss: 0.2235 - val_accuracy: 0.9104
# Epoch 20/20
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2219 - accuracy: 0.9107 - val_loss: 0.2233 - val_accuracy: 0.9112
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.feat_v2/model_binary_nn/eval.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.feat_v2/model_binary_nn/eval.png
# 2023-02-05 15:48:39.885314: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-05 15:48:39.885341: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-05 15:48:41.268488: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-05 15:48:41.268519: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rani-flashnet4): /proc/driver/nvidia/version does not exist
# 2023-02-05 15:48:41.268781: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [[1.0000000e+00 1.3368988e+04 1.6702443e+03 1.6627412e+03 1.6439240e+03
#   1.2688361e+01 1.5417907e+01 1.5368132e+01]]
# Epoch 1/20
# 474/474 [==============================] - 3s 5ms/step - loss: 0.3754 - accuracy: 0.8629 - val_loss: 0.3466 - val_accuracy: 0.8588
# Epoch 2/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.3303 - accuracy: 0.8711 - val_loss: 0.3395 - val_accuracy: 0.8646
# Epoch 3/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.3225 - accuracy: 0.8735 - val_loss: 0.3358 - val_accuracy: 0.8665
# Epoch 4/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.3169 - accuracy: 0.8744 - val_loss: 0.3274 - val_accuracy: 0.8683
# Epoch 5/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.3106 - accuracy: 0.8778 - val_loss: 0.3251 - val_accuracy: 0.8675
# Epoch 6/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.3071 - accuracy: 0.8779 - val_loss: 0.3205 - val_accuracy: 0.8688
# Epoch 7/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.3027 - accuracy: 0.8785 - val_loss: 0.3217 - val_accuracy: 0.8675
# Epoch 8/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.3000 - accuracy: 0.8803 - val_loss: 0.3188 - val_accuracy: 0.8675
# Epoch 9/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.2979 - accuracy: 0.8806 - val_loss: 0.3144 - val_accuracy: 0.8680
# Epoch 10/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.2951 - accuracy: 0.8802 - val_loss: 0.3175 - val_accuracy: 0.8683
# Epoch 11/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.2941 - accuracy: 0.8822 - val_loss: 0.3112 - val_accuracy: 0.8688
# Epoch 12/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.2925 - accuracy: 0.8820 - val_loss: 0.3108 - val_accuracy: 0.8728
# Epoch 13/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.2908 - accuracy: 0.8834 - val_loss: 0.3122 - val_accuracy: 0.8715
# Epoch 14/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.2901 - accuracy: 0.8836 - val_loss: 0.3113 - val_accuracy: 0.8725
# Epoch 15/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.2887 - accuracy: 0.8846 - val_loss: 0.3098 - val_accuracy: 0.8728
# Epoch 16/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.2882 - accuracy: 0.8846 - val_loss: 0.3112 - val_accuracy: 0.8696
# Epoch 17/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.2870 - accuracy: 0.8839 - val_loss: 0.3109 - val_accuracy: 0.8709
# Epoch 18/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.2865 - accuracy: 0.8842 - val_loss: 0.3095 - val_accuracy: 0.8733
# Epoch 19/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.2858 - accuracy: 0.8827 - val_loss: 0.3076 - val_accuracy: 0.8712
# Epoch 20/20
# 474/474 [==============================] - 2s 5ms/step - loss: 0.2853 - accuracy: 0.8844 - val_loss: 0.3065 - val_accuracy: 0.8744
# ===== output file : ../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.feat_v2.readonly/model_binary_nn/eval.stats
# ===== output figure : ../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.feat_v2.readonly/model_binary_nn/eval.png
# trace_profiles = ['../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.feat_v2.dataset', '../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.feat_v2.readonly.dataset', '../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.feat_v2.dataset', '../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.feat_v2.readonly.dataset', '../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.feat_v2.dataset', '../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.feat_v2.readonly.dataset', '../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.feat_v2.dataset', '../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.feat_v2.readonly.dataset', '../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.feat_v2.dataset', '../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.feat_v2.readonly.dataset']
#
# Training on ../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.feat_v2.dataset
#
# Training on ../dataset/nvme0n1/tencent.cut.per_50k.most_rand_iops.537/profile_v2.feat_v2.readonly.dataset
#
# Training on ../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.feat_v2.dataset
#
# Training on ../dataset/nvme0n1/tencent.cut.per_50k.most_size_thpt.222/profile_v2.feat_v2.readonly.dataset
#
# Training on ../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.feat_v2.dataset
#
# Training on ../dataset/nvme0n1/tencent.cut.per_50k.rw_60_40.490/profile_v2.feat_v2.readonly.dataset
#
# Training on ../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.feat_v2.dataset
#
# Training on ../dataset/nvme0n1/tencent.cut.per_50k.rw_65_35.211/profile_v2.feat_v2.readonly.dataset
#
# Training on ../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.feat_v2.dataset
#
# Training on ../dataset/nvme0n1/tencent.cut.per_50k.rw_75_25.379/profile_v2.feat_v2.readonly.dataset

# %% [markdown]
# ### 4. Analyze the model performance

# %%
# First, we will gather all the stats
eval "$ssh_command" /bin/bash << EOF
    cd $FLASHNET/model_collection/1_per_io_admission/script/
    source ~/.zshrc
    conda activate flashnet-trovi-env && ./gather_eval_stats.py -files ../dataset/nvme*/*cut*/profile*/*/eval.stats
EOF
# Out:
# Found 10 stats files
# ===== output file : ../dataset/models_performance.csv

# %%
eval "$ssh_command" /bin/bash << EOF
source ~/.zshrc
cd flashnet-trovi
python3 -c '
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("model_collection/1_per_io_admission/dataset/models_performance.csv")
df.head()

def plot_bars(df, column):
    # Plot the ROC-AUC value from the non read_only dataset
    df = df[df["read_only"] == False]
    fig, ax = plt.subplots(figsize=(5, 4))
    # creating the bar plot
    plt.bar(df["trace_name"].tolist(), df[column].tolist(), color =[np.random.rand(3,) for x in range(len(df))], width = 0.4)
    plt.setp( ax.xaxis.get_majorticklabels(), rotation=30, ha="right" )
    # ax.yaxis.set_ticks(np.arange(0, 1.1, 0.2))
    plt.xlabel("Dataset name")
    plt.ylabel(column.upper())
    plt.title(column.upper() + " on Various Dataset")
    # plt.ylim(0,1)
    plt.show()
    plt.savefig(column+".png")

plot_bars(df, "roc_auc")
plot_bars(df, "fnr")
plot_bars(df, "fpr")'

EOF

# %% [markdown]
# View output in $FLASHNET
